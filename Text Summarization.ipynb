# %%
#Imports
import nltk
import re
import numpy as np
import pickle
from nltk.corpus import stopwords
from sklearn.datasets import load_files
import bs4 as bs

# %%
import urllib.request

# %%
# pulling data
source = urllib.request.urlopen("https://en.wikipedia.org/wiki/Climate_change").read()

# %%
source

# %%
#!pip install lxml

# %%
soup = bs.BeautifulSoup(source, 'lxml')

# %%
soup

# %% [markdown]
# # Data Extraction

# %%
text_raw = ""
for paragraph in soup.find_all('p'):
    text_raw += paragraph.text

# %%
text_raw

# %% [markdown]
# # Data Preprocessing

# %%
text = re.sub(r'\[[0-9]*\]', ' ', text_raw)
text = re.sub(r'\s+', ' ', text)
clean_text = text.lower()
clean_text = re.sub(r'\W', ' ', clean_text)
clean_text = re.sub(r'\d', ' ', clean_text)
clean_text = re.sub(r'\s+', ' ', clean_text)

# %%
clean_text

# %% [markdown]
# # Tokenize Sentences

# %%
sentences = nltk.sent_tokenize(text)

# %%
len(sentences)
# Out:
# 475

# %% [markdown]
# # Word Count / Histogram

# %%
stop_words = stopwords.words('english')

# %%
word_count = dict()
for word in nltk.word_tokenize(clean_text):
    if word not in stop_words:
        if word not in word_count.keys(): word_count[word] = 1
        else: word_count[word] += 1

# %%
word_count
# Out:
# {'contemporary': 2,
#  'climate': 138,
#  'change': 84,
#  'includes': 2,
#  'global': 55,
#  'warming': 75,
#  'impacts': 20,
#  'earth': 24,
#  'weather': 7,
#  'patterns': 5,
#  'previous': 1,
#  'periods': 1,
#  'current': 10,
#  'changes': 23,
#  'distinctly': 1,
#  'rapid': 5,
#  'due': 14,
#  'natural': 15,
#  'causes': 5,
#  'instead': 5,
#  'caused': 8,
#  'emission': 3,
#  'greenhouse': 40,
#  'gases': 27,
#  'mostly': 2,
#  'carbon': 44,
#  'dioxide': 7,
#  'co': 48,
#  'methane': 10,
#  'burning': 5,
#  'fossil': 15,
#  'fuels': 9,
#  'energy': 40,
#  'use': 17,
#  'creates': 1,
#  'emissions': 63,
#  'agriculture': 8,
#  'steelmaking': 1,
#  'cement': 3,
#  'production': 9,
#  'forest': 9,
#  'loss': 7,
#  'additional': 7,
#  'sources': 2,
#  'transparent': 4,
#  'sunlight': 14,
#  'allowing': 1,
#  'heat': 34,
#  'surface': 21,
#  'emits': 1,
#  'infrared': 3,
#  'radiation': 6,
#  'absorb': 7,
#  'trapping': 2,
#  'near': 5,
#  'planet': 5,
#  'heats': 2,
#  'like': 10,
#  'reflecting': 4,
#  'snow': 7,
#  'cover': 6,
#  'amplifying': 2,
#  'land': 26,
#  'temperatures': 11,
#  'risen': 3,
#  'twice': 4,
#  'fast': 3,
#  'average': 4,
#  'deserts': 3,
#  'expanding': 3,
#  'waves': 4,
#  'wildfires': 2,
#  'becoming': 2,
#  'common': 3,
#  'increased': 26,
#  'arctic': 14,
#  'contributed': 3,
#  'melting': 6,
#  'permafrost': 4,
#  'glacial': 2,
#  'retreat': 2,
#  'sea': 18,
#  'ice': 25,
#  'higher': 14,
#  'also': 29,
#  'causing': 5,
#  'intense': 1,
#  'storms': 1,
#  'extremes': 1,
#  'environmental': 10,
#  'mountains': 1,
#  'coral': 2,
#  'reefs': 3,
#  'forcing': 7,
#  'many': 12,
#  'species': 6,
#  'relocate': 1,
#  'become': 5,
#  'extinct': 1,
#  'threatens': 2,
#  'people': 17,
#  'food': 12,
#  'water': 14,
#  'scarcity': 1,
#  'flooding': 7,
#  'extreme': 6,
#  'disease': 1,
#  'economic': 7,
#  'human': 14,
#  'migration': 4,
#  'conflict': 3,
#  'result': 4,
#  'world': 11,
#  'health': 7,
#  'organization': 2,
#  'calls': 1,
#  'greatest': 3,
#  'threat': 3,
#  'st': 7,
#  'century': 14,
#  'even': 6,
#  'efforts': 2,
#  'minimise': 2,
#  'future': 10,
#  'successful': 1,
#  'effects': 11,
#  'continue': 7,
#  'centuries': 4,
#  'include': 11,
#  'level': 19,
#  'rise': 19,
#  'warmer': 4,
#  'acidic': 1,
#  'oceans': 10,
#  'already': 3,
#  'felt': 1,
#  'c': 37,
#  'increase': 20,
#  'may': 19,
#  'trigger': 2,
#  'tipping': 2,
#  'points': 2,
#  'greenland': 3,
#  'sheet': 2,
#  'paris': 7,
#  'agreement': 14,
#  'nations': 6,
#  'collectively': 1,
#  'agreed': 1,
#  'keep': 2,
#  'well': 5,
#  'however': 9,
#  'pledges': 4,
#  'made': 6,
#  'would': 26,
#  'still': 4,
#  'reach': 4,
#  'end': 3,
#  'limiting': 8,
#  'require': 3,
#  'halving': 2,
#  'achieving': 1,
#  'net': 8,
#  'zero': 3,
#  'making': 5,
#  'deep': 3,
#  'cuts': 1,
#  'switching': 5,
#  'away': 1,
#  'towards': 3,
#  'using': 1,
#  'electricity': 8,
#  'generated': 1,
#  'low': 14,
#  'phasing': 1,
#  'coal': 7,
#  'fired': 1,
#  'power': 10,
#  'plants': 5,
#  'vastly': 1,
#  'increasing': 11,
#  'wind': 9,
#  'solar': 16,
#  'electric': 3,
#  'vehicles': 4,
#  'pumps': 3,
#  'buildings': 3,
#  'taking': 2,
#  'measures': 2,
#  'conserve': 1,
#  'removed': 1,
#  'atmosphere': 22,
#  'instance': 7,
#  'communities': 3,
#  'adapt': 8,
#  'better': 3,
#  'coastline': 1,
#  'protection': 4,
#  'avert': 2,
#  'risk': 12,
#  'severe': 7,
#  'widespread': 2,
#  'permanent': 2,
#  'unclear': 2,
#  'whether': 3,
#  'dominate': 1,
#  'aerosol': 1,
#  'induced': 2,
#  'cooling': 8,
#  'scientists': 9,
#  'often': 7,
#  'used': 10,
#  'term': 9,
#  'inadvertent': 1,
#  'modification': 1,
#  'refer': 2,
#  'impact': 3,
#  'terms': 3,
#  'popularised': 1,
#  'former': 1,
#  'refers': 2,
#  'latter': 2,
#  'describes': 1,
#  'full': 1,
#  'effect': 13,
#  'became': 2,
#  'popular': 2,
#  'nasa': 1,
#  'scientist': 1,
#  'james': 2,
#  'hansen': 2,
#  'testimony': 2,
#  'u': 1,
#  'senate': 1,
#  'popularity': 2,
#  'usually': 1,
#  'system': 10,
#  'whereas': 3,
#  'anthropogenic': 5,
#  'two': 7,
#  'interchangeably': 1,
#  'various': 3,
#  'politicians': 1,
#  'media': 3,
#  'figures': 1,
#  'adopted': 1,
#  'crisis': 1,
#  'emergency': 5,
#  'talk': 1,
#  'heating': 5,
#  'policy': 4,
#  'editor': 1,
#  'chief': 1,
#  'guardian': 1,
#  'said': 1,
#  'included': 3,
#  'language': 1,
#  'editorial': 1,
#  'guidelines': 2,
#  'ensure': 1,
#  'scientifically': 1,
#  'precise': 1,
#  'communicating': 1,
#  'clearly': 1,
#  'readers': 1,
#  'important': 1,
#  'issue': 1,
#  'oxford': 1,
#  'languages': 1,
#  'chose': 1,
#  'word': 1,
#  'year': 6,
#  'defining': 1,
#  'situation': 1,
#  'urgent': 2,
#  'action': 6,
#  'required': 3,
#  'reduce': 14,
#  'halt': 1,
#  'avoid': 1,
#  'potentially': 2,
#  'irreversible': 3,
#  'damage': 2,
#  'resulting': 2,
#  'multiple': 1,
#  'independent': 2,
#  'instrumental': 1,
#  'datasets': 1,
#  'show': 2,
#  'decade': 4,
#  'warmed': 5,
#  'compared': 3,
#  'pre': 3,
#  'industrial': 10,
#  'baseline': 1,
#  'rising': 8,
#  'per': 8,
#  'reaching': 7,
#  'temperature': 20,
#  'era': 3,
#  'since': 12,
#  'number': 2,
#  'cold': 1,
#  'days': 2,
#  'nights': 2,
#  'decreased': 1,
#  'warm': 3,
#  'little': 3,
#  'th': 3,
#  'mid': 2,
#  'information': 3,
#  'period': 5,
#  'comes': 3,
#  'proxies': 1,
#  'trees': 2,
#  'cores': 1,
#  'thermometer': 1,
#  'records': 1,
#  'began': 1,
#  'provide': 3,
#  'coverage': 2,
#  'around': 6,
#  'historical': 2,
#  'medieval': 1,
#  'anomaly': 1,
#  'age': 4,
#  'occur': 5,
#  'time': 9,
#  'across': 5,
#  'different': 7,
#  'regions': 15,
#  'reached': 3,
#  'high': 11,
#  'late': 3,
#  'limited': 2,
#  'set': 9,
#  'prehistorical': 1,
#  'episodes': 1,
#  'paleocene': 1,
#  'eocene': 1,
#  'thermal': 3,
#  'maximum': 1,
#  'modern': 2,
#  'observed': 6,
#  'concentrations': 10,
#  'abrupt': 2,
#  'geophysical': 1,
#  'events': 4,
#  'history': 1,
#  'approach': 2,
#  'rates': 2,
#  'evidence': 5,
#  'air': 15,
#  'measurements': 3,
#  'reinforced': 1,
#  'wide': 3,
#  'range': 5,
#  'observations': 4,
#  'frequency': 3,
#  'intensity': 2,
#  'heavy': 3,
#  'precipitation': 3,
#  'atmospheric': 8,
#  'humidity': 2,
#  'flora': 1,
#  'fauna': 1,
#  'behaving': 1,
#  'manner': 1,
#  'consistent': 2,
#  'flowering': 1,
#  'earlier': 1,
#  'spring': 1,
#  'another': 3,
#  'key': 4,
#  'indicator': 1,
#  'upper': 2,
#  'demonstrates': 1,
#  'preventing': 3,
#  'radiating': 2,
#  'space': 6,
#  'differing': 1,
#  'pattern': 1,
#  'emitted': 2,
#  'persist': 1,
#  'long': 6,
#  'enough': 2,
#  'diffuse': 1,
#  'almost': 4,
#  'larger': 3,
#  'capacity': 4,
#  'lose': 2,
#  'evaporation': 2,
#  'grown': 1,
#  'brief': 1,
#  'pauses': 1,
#  'least': 2,
#  'extra': 1,
#  'stored': 2,
#  'ocean': 18,
#  'rest': 2,
#  'heated': 2,
#  'melted': 2,
#  'continents': 2,
#  'northern': 3,
#  'hemisphere': 3,
#  'north': 3,
#  'pole': 2,
#  'much': 5,
#  'faster': 2,
#  'south': 3,
#  'southern': 2,
#  'seasonal': 2,
#  'surfaces': 1,
#  'flip': 1,
#  'lot': 1,
#  'light': 1,
#  'dark': 2,
#  'start': 1,
#  'absorbing': 1,
#  'local': 3,
#  'black': 3,
#  'deposits': 2,
#  'contribute': 2,
#  'rate': 6,
#  'glaciers': 2,
#  'sheets': 4,
#  'disrupts': 1,
#  'circulation': 6,
#  'including': 4,
#  'weakened': 1,
#  'gulf': 1,
#  'stream': 1,
#  'changing': 3,
#  'experiences': 1,
#  'cycles': 1,
#  'last': 5,
#  'years': 13,
#  'el': 1,
#  'niño': 1,
#  'oscillation': 1,
#  'decades': 5,
#  'imbalance': 2,
#  'external': 5,
#  'always': 1,
#  'examples': 1,
#  'forcings': 3,
#  'luminosity': 1,
#  'volcanic': 6,
#  'eruptions': 2,
#  'variations': 3,
#  'orbit': 2,
#  'sun': 7,
#  'determine': 2,
#  'contribution': 2,
#  'known': 2,
#  'internal': 1,
#  'variability': 4,
#  'need': 5,
#  'ruled': 2,
#  'unique': 1,
#  'fingerprints': 2,
#  'potential': 2,
#  'compare': 1,
#  'example': 3,
#  'major': 9,
#  'cause': 7,
#  'fingerprint': 1,
#  'entire': 1,
#  'yet': 1,
#  'lower': 6,
#  'gas': 22,
#  'attribution': 1,
#  'recent': 5,
#  'shows': 1,
#  'main': 4,
#  'driver': 1,
#  'elevated': 2,
#  'aerosols': 8,
#  'dampening': 1,
#  'absorbs': 2,
#  'radiates': 1,
#  'reemit': 1,
#  'slowing': 2,
#  'pass': 1,
#  'escape': 1,
#  'revolution': 2,
#  'naturally': 3,
#  'occurring': 2,
#  'amounts': 2,
#  'absence': 1,
#  'vapour': 7,
#  'clouds': 9,
#  'biggest': 1,
#  'contributors': 1,
#  'function': 1,
#  'therefore': 2,
#  'feedbacks': 10,
#  'hand': 1,
#  'tropospheric': 1,
#  'ozone': 4,
#  'cfcs': 1,
#  'nitrous': 3,
#  'oxide': 3,
#  'dependent': 2,
#  'activity': 4,
#  'mainly': 2,
#  'extracting': 1,
#  'oil': 3,
#  'amount': 7,
#  'radiative': 3,
#  'respectively': 2,
#  'levels': 14,
#  'million': 5,
#  'far': 3,
#  'excluding': 1,
#  'equivalent': 2,
#  'billion': 3,
#  'tonnes': 1,
#  'fluorinated': 1,
#  'primarily': 2,
#  'come': 4,
#  'transport': 9,
#  'manufacturing': 2,
#  'deforestation': 7,
#  'processes': 6,
#  'released': 3,
#  'chemical': 3,
#  'reactions': 1,
#  'steel': 2,
#  'aluminum': 1,
#  'fertiliser': 2,
#  'livestock': 1,
#  'manure': 1,
#  'rice': 1,
#  'cultivation': 2,
#  'landfills': 1,
#  'wastewater': 1,
#  'mining': 1,
#  'extraction': 1,
#  'largely': 2,
#  'microbial': 1,
#  'decomposition': 1,
#  'despite': 1,
#  'particularly': 3,
#  'forests': 4,
#  'remain': 1,
#  'significant': 9,
#  'sink': 5,
#  'fixation': 1,
#  'soil': 2,
#  'photosynthesis': 1,
#  'offset': 1,
#  'contributions': 1,
#  'estimated': 7,
#  'remove': 1,
#  'annual': 2,
#  'serves': 1,
#  'via': 2,
#  'step': 1,
#  'process': 3,
#  'first': 4,
#  'dissolves': 1,
#  'afterwards': 1,
#  'overturning': 2,
#  'distributes': 1,
#  'interior': 1,
#  'accumulates': 1,
#  'part': 1,
#  'cycle': 5,
#  'absorbed': 4,
#  'pollution': 5,
#  'form': 6,
#  'puts': 1,
#  'large': 10,
#  'burden': 1,
#  'affects': 2,
#  'scale': 6,
#  'gradual': 1,
#  'reduction': 7,
#  'phenomenon': 1,
#  'popularly': 1,
#  'dimming': 1,
#  'typically': 4,
#  'attributed': 1,
#  'biofuel': 1,
#  'fuel': 8,
#  'globally': 3,
#  'declining': 1,
#  'meaning': 1,
#  'longer': 3,
#  'mask': 1,
#  'scatter': 1,
#  'indirect': 4,
#  'budget': 3,
#  'sulfate': 1,
#  'act': 2,
#  'cloud': 3,
#  'condensation': 1,
#  'nuclei': 1,
#  'lead': 4,
#  'smaller': 2,
#  'droplets': 2,
#  'reflect': 2,
#  'efficiently': 1,
#  'fewer': 1,
#  'growth': 9,
#  'raindrops': 1,
#  'makes': 8,
#  'reflective': 1,
#  'incoming': 2,
#  'largest': 5,
#  'uncertainty': 5,
#  'limit': 10,
#  'soot': 1,
#  'falls': 1,
#  'absorption': 1,
#  'increases': 8,
#  'new': 5,
#  'could': 13,
#  'humans': 6,
#  'create': 1,
#  'agricultural': 6,
#  'today': 1,
#  'takes': 4,
#  'area': 1,
#  'uninhabitable': 2,
#  'etc': 1,
#  'forested': 1,
#  'continues': 1,
#  'decrease': 1,
#  'conversion': 2,
#  'cropland': 1,
#  'tropics': 1,
#  'aspect': 2,
#  'affecting': 3,
#  'producing': 1,
#  'products': 4,
#  'beef': 1,
#  'palm': 1,
#  'logging': 1,
#  'produce': 6,
#  'forestry': 4,
#  'short': 3,
#  'shifting': 1,
#  'affect': 5,
#  'type': 1,
#  'vegetation': 1,
#  'region': 1,
#  'gets': 1,
#  'reflected': 2,
#  'back': 3,
#  'albedo': 4,
#  'lost': 3,
#  'grassland': 1,
#  'lighter': 1,
#  'modifying': 1,
#  'release': 4,
#  'compounds': 1,
#  'influence': 1,
#  'tropic': 1,
#  'temperate': 1,
#  'areas': 6,
#  'latitudes': 2,
#  'closer': 1,
#  'poles': 2,
#  'gain': 1,
#  'replaced': 2,
#  'leads': 3,
#  'led': 3,
#  'slight': 1,
#  'dominated': 1,
#  'physical': 6,
#  'models': 16,
#  'unable': 1,
#  'reproduce': 2,
#  'account': 1,
#  'output': 2,
#  'primary': 2,
#  'source': 2,
#  'directly': 2,
#  'irradiance': 1,
#  'measured': 1,
#  'satellites': 1,
#  'available': 3,
#  'early': 3,
#  'onwards': 2,
#  'upward': 1,
#  'trend': 2,
#  'troposphere': 2,
#  'coupled': 1,
#  'stratosphere': 3,
#  'responsible': 4,
#  'explosive': 1,
#  'represent': 2,
#  'eruption': 1,
#  'sufficiently': 1,
#  'strong': 2,
#  'sulfur': 1,
#  'partially': 1,
#  'blocked': 1,
#  'couple': 1,
#  'signal': 1,
#  'lasts': 1,
#  'negligible': 1,
#  'trends': 1,
#  'present': 2,
#  'day': 2,
#  'less': 13,
#  'response': 3,
#  'initial': 1,
#  'modified': 1,
#  'self': 2,
#  'reinforcing': 2,
#  'reduced': 8,
#  'balancing': 2,
#  'feedback': 6,
#  'mechanism': 1,
#  'gives': 1,
#  'addition': 3,
#  'fertilizing': 1,
#  'plant': 3,
#  'reason': 1,
#  'project': 3,
#  'magnitudes': 1,
#  'given': 1,
#  'hold': 2,
#  'moisture': 1,
#  'potent': 1,
#  'thinner': 1,
#  'insulator': 1,
#  'downwards': 1,
#  'reduces': 2,
#  'reflectivity': 1,
#  'contributing': 1,
#  'amplification': 2,
#  'releases': 2,
#  'wetlands': 3,
#  'marine': 2,
#  'systems': 5,
#  'freshwater': 2,
#  'overall': 3,
#  'expected': 8,
#  'increasingly': 3,
#  'positive': 2,
#  'half': 2,
#  'extended': 3,
#  'growing': 2,
#  'season': 2,
#  'stimulated': 1,
#  'droughts': 3,
#  'inhibit': 1,
#  'uncertain': 5,
#  'grow': 1,
#  'soils': 1,
#  'contain': 1,
#  'quantities': 1,
#  'acidifies': 1,
#  'phytoplankton': 1,
#  'decreasing': 2,
#  'fraction': 1,
#  'model': 5,
#  'representation': 1,
#  'biological': 1,
#  'calculate': 1,
#  'degree': 2,
#  'accounting': 1,
#  'strength': 1,
#  'estimating': 1,
#  'predict': 2,
#  'seasons': 1,
#  'flows': 1,
#  'realism': 1,
#  'tested': 1,
#  'examining': 1,
#  'ability': 1,
#  'simulate': 2,
#  'past': 4,
#  'climates': 2,
#  'underestimated': 3,
#  'shrinkage': 2,
#  'older': 2,
#  'agree': 1,
#  'united': 5,
#  'states': 4,
#  'published': 4,
#  'national': 5,
#  'assessment': 3,
#  'notes': 1,
#  'underestimating': 1,
#  'missing': 1,
#  'relevant': 1,
#  'subset': 1,
#  'add': 1,
#  'societal': 1,
#  'factors': 3,
#  'simple': 1,
#  'population': 1,
#  'interact': 1,
#  'scenarios': 6,
#  'input': 1,
#  'generate': 2,
#  'projections': 2,
#  'others': 1,
#  'combined': 2,
#  'modelling': 3,
#  'might': 2,
#  'according': 2,
#  'concentration': 2,
#  'ppm': 1,
#  'depending': 1,
#  'socioeconomic': 1,
#  'scenario': 6,
#  'mitigation': 10,
#  'ipcc': 5,
#  'sixth': 1,
#  'report': 2,
#  'projects': 3,
#  'likely': 6,
#  'ghg': 2,
#  'intermediate': 1,
#  'based': 6,
#  'combination': 3,
#  'remaining': 2,
#  'determined': 2,
#  'sensitivity': 1,
#  'kept': 1,
#  'thirds': 2,
#  'chance': 3,
#  'exceed': 2,
#  'gigatonnes': 2,
#  'corresponds': 1,
#  'uncertainties': 1,
#  'clear': 1,
#  'resources': 3,
#  'abundant': 1,
#  'shortages': 2,
#  'relied': 1,
#  'broad': 1,
#  'gradually': 1,
#  'rapidly': 1,
#  'studying': 1,
#  'appeared': 1,
#  'simultaneously': 2,
#  'extremely': 2,
#  'wet': 1,
#  'dry': 4,
#  'within': 5,
#  'monsoon': 1,
#  'india': 2,
#  'east': 2,
#  'asia': 3,
#  'rainfall': 3,
#  'hurricanes': 1,
#  'typhoons': 1,
#  'tropical': 2,
#  'cyclones': 2,
#  'study': 1,
#  'review': 1,
#  'article': 1,
#  'nature': 1,
#  'geoscience': 1,
#  'concluded': 3,
#  'geographic': 2,
#  'probably': 2,
#  'expand': 1,
#  'poleward': 2,
#  'hadley': 1,
#  'consequence': 2,
#  'melt': 6,
#  'antarctica': 1,
#  'expansion': 4,
#  'averaging': 1,
#  'mm': 1,
#  'cm': 1,
#  'warmth': 1,
#  'undermining': 1,
#  'threatening': 1,
#  'unplug': 1,
#  'antarctic': 2,
#  'glacier': 2,
#  'outlets': 1,
#  'risking': 1,
#  'possibility': 1,
#  'meter': 1,
#  'shrinking': 1,
#  'thinning': 1,
#  'free': 2,
#  'summers': 1,
#  'rare': 1,
#  'degrees': 1,
#  'every': 3,
#  'three': 1,
#  'ten': 1,
#  'chemistry': 1,
#  'dissolved': 1,
#  'acidify': 1,
#  'oxygen': 5,
#  'soluble': 1,
#  'dead': 1,
#  'zones': 2,
#  'greater': 6,
#  'passing': 1,
#  'thresholds': 1,
#  'beyond': 3,
#  'certain': 2,
#  'avoided': 1,
#  'collapse': 3,
#  'west': 1,
#  'commit': 1,
#  'although': 4,
#  'depends': 1,
#  'currents': 1,
#  'particular': 4,
#  'concern': 3,
#  'shutdown': 1,
#  'atlantic': 2,
#  'meridional': 1,
#  'europe': 1,
#  'america': 1,
#  'acidification': 3,
#  'timescale': 1,
#  'millennia': 1,
#  'magnitude': 1,
#  'lifetime': 1,
#  'oceanic': 1,
#  'uptake': 1,
#  'slow': 2,
#  'hundreds': 1,
#  'thousands': 1,
#  'prolonged': 1,
#  'interglacial': 1,
#  'metres': 1,
#  'celsius': 1,
#  'ft': 1,
#  'f': 1,
#  'driven': 1,
#  'terrestrial': 1,
#  'altitudes': 1,
#  'resulted': 1,
#  'greening': 1,
#  'heatwaves': 2,
#  'drought': 2,
#  'ecosystem': 3,
#  'productivity': 3,
#  'balance': 1,
#  'opposing': 1,
#  'drier': 1,
#  'subtropics': 1,
#  'size': 1,
#  'speed': 1,
#  'ecosystems': 10,
#  'extinction': 2,
#  'slowly': 1,
#  'animals': 2,
#  'migrated': 1,
#  'colder': 1,
#  'frequently': 1,
#  'harming': 1,
#  'organisms': 2,
#  'corals': 2,
#  'kelp': 1,
#  'seabirds': 1,
#  'harder': 1,
#  'mussels': 1,
#  'barnacles': 1,
#  'shells': 1,
#  'skeletons': 1,
#  'bleached': 1,
#  'harmful': 1,
#  'algal': 1,
#  'blooms': 1,
#  'enhanced': 2,
#  'eutrophication': 1,
#  'disrupt': 1,
#  'webs': 1,
#  'great': 2,
#  'life': 2,
#  'coastal': 5,
#  'stress': 2,
#  'disappeared': 1,
#  'ecological': 1,
#  'bleaching': 1,
#  'damaged': 1,
#  'barrier': 1,
#  'reef': 1,
#  'worldwide': 3,
#  'worsened': 2,
#  'bushfires': 1,
#  'australia': 2,
#  'thaws': 1,
#  'undermine': 1,
#  'infrastructure': 2,
#  'habitat': 1,
#  'destruction': 1,
#  'rely': 2,
#  'disappearing': 1,
#  'pest': 1,
#  'propagation': 1,
#  'mild': 1,
#  'winters': 1,
#  ...}

# %% [markdown]
# # Weighted Histogram

# %%
max_count = max(word_count.values())

# %%
for key in word_count.keys():
    word_count[key] = word_count[key]/max_count

# %%
word_count
# Out:
# {'contemporary': 0.014492753623188406,
#  'climate': 1.0,
#  'change': 0.6086956521739131,
#  'includes': 0.014492753623188406,
#  'global': 0.39855072463768115,
#  'warming': 0.5434782608695652,
#  'impacts': 0.14492753623188406,
#  'earth': 0.17391304347826086,
#  'weather': 0.050724637681159424,
#  'patterns': 0.036231884057971016,
#  'previous': 0.007246376811594203,
#  'periods': 0.007246376811594203,
#  'current': 0.07246376811594203,
#  'changes': 0.16666666666666666,
#  'distinctly': 0.007246376811594203,
#  'rapid': 0.036231884057971016,
#  'due': 0.10144927536231885,
#  'natural': 0.10869565217391304,
#  'causes': 0.036231884057971016,
#  'instead': 0.036231884057971016,
#  'caused': 0.057971014492753624,
#  'emission': 0.021739130434782608,
#  'greenhouse': 0.2898550724637681,
#  'gases': 0.1956521739130435,
#  'mostly': 0.014492753623188406,
#  'carbon': 0.3188405797101449,
#  'dioxide': 0.050724637681159424,
#  'co': 0.34782608695652173,
#  'methane': 0.07246376811594203,
#  'burning': 0.036231884057971016,
#  'fossil': 0.10869565217391304,
#  'fuels': 0.06521739130434782,
#  'energy': 0.2898550724637681,
#  'use': 0.12318840579710146,
#  'creates': 0.007246376811594203,
#  'emissions': 0.45652173913043476,
#  'agriculture': 0.057971014492753624,
#  'steelmaking': 0.007246376811594203,
#  'cement': 0.021739130434782608,
#  'production': 0.06521739130434782,
#  'forest': 0.06521739130434782,
#  'loss': 0.050724637681159424,
#  'additional': 0.050724637681159424,
#  'sources': 0.014492753623188406,
#  'transparent': 0.028985507246376812,
#  'sunlight': 0.10144927536231885,
#  'allowing': 0.007246376811594203,
#  'heat': 0.2463768115942029,
#  'surface': 0.15217391304347827,
#  'emits': 0.007246376811594203,
#  'infrared': 0.021739130434782608,
#  'radiation': 0.043478260869565216,
#  'absorb': 0.050724637681159424,
#  'trapping': 0.014492753623188406,
#  'near': 0.036231884057971016,
#  'planet': 0.036231884057971016,
#  'heats': 0.014492753623188406,
#  'like': 0.07246376811594203,
#  'reflecting': 0.028985507246376812,
#  'snow': 0.050724637681159424,
#  'cover': 0.043478260869565216,
#  'amplifying': 0.014492753623188406,
#  'land': 0.18840579710144928,
#  'temperatures': 0.07971014492753623,
#  'risen': 0.021739130434782608,
#  'twice': 0.028985507246376812,
#  'fast': 0.021739130434782608,
#  'average': 0.028985507246376812,
#  'deserts': 0.021739130434782608,
#  'migrated': 0.007246376811594203,
#  'colder': 0.007246376811594203,
#  'frequently': 0.007246376811594203,
#  'harming': 0.007246376811594203,
#  'organisms': 0.014492753623188406,
#  'corals': 0.014492753623188406,
#  'kelp': 0.007246376811594203,
#  'seabirds': 0.007246376811594203,
#  'harder': 0.007246376811594203,
#  'mussels': 0.007246376811594203,
#  'barnacles': 0.007246376811594203,
#  'shells': 0.007246376811594203,
#  'skeletons': 0.007246376811594203,
#  'bleached': 0.007246376811594203,
#  'harmful': 0.007246376811594203,
#  'algal': 0.007246376811594203,
#  'blooms': 0.007246376811594203,
#  'enhanced': 0.014492753623188406,
#  'eutrophication': 0.007246376811594203,
#  'disrupt': 0.007246376811594203,
#  'webs': 0.007246376811594203,
#  'great': 0.014492753623188406,
#  'life': 0.014492753623188406,
#  'coastal': 0.036231884057971016,
#  'stress': 0.014492753623188406,
#  'disappeared': 0.007246376811594203,
#  'ecological': 0.007246376811594203,
#  'bleaching': 0.007246376811594203,
#  'damaged': 0.007246376811594203,
#  'barrier': 0.007246376811594203,
#  'reef': 0.007246376811594203,
#  'worldwide': 0.021739130434782608,
#  'worsened': 0.014492753623188406,
#  'bushfires': 0.007246376811594203,
#  'australia': 0.014492753623188406,
#  'thaws': 0.007246376811594203,
#  'undermine': 0.007246376811594203,
#  'infrastructure': 0.014492753623188406,
#  'habitat': 0.007246376811594203,
#  'destruction': 0.007246376811594203,
#  'rely': 0.014492753623188406,
#  'disappearing': 0.007246376811594203,
#  'pest': 0.007246376811594203,
#  'propagation': 0.007246376811594203,
#  'mild': 0.007246376811594203,
#  'winters': 0.007246376811594203,
#  ...}

# %% [markdown]
# # Sentences Scores

# %%
sent_scores = dict()
for sentence in sentences:
    for word in nltk.word_tokenize(sentence.lower()):
        if word in word_count.keys():
            if len(sentence.split(" ")) < 25:
                if sentence not in sent_scores: sent_scores[sentence] = word_count[word]
                else: sent_scores[sentence] += word_count[word]

# %%
sent_scores = dict()
for sentence in sentences:
    if len(sentence.split(" ")) < 25:        # checking the sentence first
        for word in nltk.word_tokenize(sentence.lower()):
            if word in word_count.keys():
                if sentence not in sent_scores: sent_scores[sentence] = word_count[word]
                else: sent_scores[sentence] += word_count[word]

# %%
sent_scores
# Out:
# {" Contemporary climate change includes both global warming and its impacts on Earth's weather patterns.": 2.985507246376812,
#  'There have been previous periods of climate change, but the current changes are distinctly more rapid and not due to natural causes.': 2.152173913043479,
#  'Instead, they are caused by the emission of greenhouse gases, mostly carbon dioxide (CO2) and methane.': 1.0579710144927537,
#  'Burning fossil fuels for energy use creates most of these emissions.': 1.0869565217391304,
#  'Agriculture, steelmaking, cement production, and forest loss are additional sources.': 0.33333333333333337,
#  "Greenhouse gases are transparent to sunlight, allowing it through to heat the Earth's surface.": 1.1956521739130437,
#  "When the Earth emits that heat as infrared radiation the gases absorb it, trapping the heat near the Earth's surface.": 1.3623188405797102,
#  'As the planet heats up it causes changes like the loss of sunlight-reflecting snow cover, amplifying global warming.': 1.4275362318840579,
#  'On land, temperatures have risen about twice as fast as the global average.': 0.7681159420289855,
#  'Deserts are expanding, while heat waves and wildfires are becoming more common.': 0.3695652173913044,
#  'Increased warming in the Arctic has contributed to melting permafrost, glacial retreat and sea ice loss.': 1.3188405797101446,
#  'Higher temperatures are also causing more intense storms and other weather extremes.': 0.4999999999999999,
#  'Rapid environmental change in mountains, coral reefs, and the Arctic is forcing many species to relocate or become extinct.': 1.0942028985507246,
#  'Climate change threatens people with food and water scarcity, increased flooding, extreme heat, more disease, and economic loss.': 2.579710144927537,
#  'Human migration and conflict can be a result.': 0.18115942028985507,
#  'The World Health Organization calls climate change the greatest threat to global health in the 21st century.': 2.3550724637681157,
#  'Even if efforts to minimise future warming are successful, some effects will continue for centuries.': 0.855072463768116,
#  'These include sea level rise, and warmer, more acidic oceans.': 0.5942028985507246,
#  'Many of these impacts are already felt at the current level of warming (1.2 °C).': 1.0144927536231885,
#  'Additional warming will increase these impacts and may trigger tipping points, such as the melting of the Greenland ice sheet.': 1.3260869565217392,
#  'Under the 2015 Paris Agreement, nations collectively agreed to keep warming "well under 2 °C".': 0.8043478260869565,
#  'However, with pledges made under the Agreement, global warming would still reach about 2.7 °C by the end of the century.': 1.5507246376811592,
#  'Limiting warming to 1.5 °C will require halving emissions by 2030 and achieving net-zero emissions by 2050.': 1.5579710144927537,
#  'Making deep cuts in emissions will require switching away from burning fossil fuels and towards using electricity generated from low-carbon sources.': 0.9057971014492755,
#  'Carbon can also be removed from the atmosphere, for instance by increasing forest cover.': 0.9347826086956521,
#  'While communities may adapt to climate change through efforts like better coastline protection, they cannot avert the risk of severe, widespread, and permanent impacts.': 2.2971014492753628,
#  'Before the 1980s, it was unclear whether warming by increased greenhouse gases would dominate aerosol-induced cooling.': 1.5072463768115942,
#  'Scientists then often used the term inadvertent climate modification to refer to the human impact on the climate.': 2.4057971014492754,
#  'In the 1980s, the terms global warming and climate change were popularised.': 2.579710144927536,
#  'The former refers only to increased surface warming, the latter describes the full effect of greenhouse gases on the climate.': 2.5144927536231885,
#  'Global warming became the most popular term after NASA climate scientist James Hansen used it in his 1988 testimony in the U.S. Senate.': 2.173913043478261,
#  'In the 2000s, the term climate change increased in popularity.': 1.8768115942028987,
#  'Global warming usually refers to human-induced warming of the Earth system, whereas climate change can refer to natural or anthropogenic change.': 4.1521739130434785,
#  'The two terms are often used interchangeably.': 0.2028985507246377,
#  'Multiple independent instrumental datasets show that the climate system is warming.': 1.6666666666666667,
#  'The 2011–2020 decade warmed to an average 1.09 °C [0.95–1.20 °C] compared to the pre-industrial baseline (1850–1900).': 0.12318840579710146,
#  'Surface temperatures are rising by about 0.2 °C per decade, with 2020 reaching a temperature of 1.2 °C above the pre-industrial era.': 0.5942028985507246,
#  'Since 1950, the number of cold days and nights has decreased, and the number of warm days and nights has increased.': 0.3985507246376812,
#  'There was little net warming between the 18th century and the mid-19th century.': 0.8260869565217391,
#  'Climate information for that period comes from climate proxies, such as trees and ice cores.': 2.289855072463768,
#  'Thermometer records began to provide global coverage around 1850.': 0.5,
#  'Temperatures may have reached as high as those of the late-20th century in a limited set of regions.': 0.6086956521739131,
#  'There have been prehistorical episodes of global warming, such as the Paleocene–Eocene Thermal Maximum.': 0.9855072463768116,
#  'Evidence of warming from air temperature measurements are reinforced with a wide range of other observations.': 0.9492753623188407,
#  'There has been an increase in the frequency and intensity of heavy precipitation, melting of snow and land ice, and increased atmospheric humidity.': 0.9492753623188407,
#  'Flora and fauna are also behaving in a manner consistent with warming; for instance, plants are flowering earlier in spring.': 0.9057971014492755,
#  'Regions of the world warm at differing rates.': 0.2318840579710145,
#  'The pattern is independent of where greenhouse gases are emitted, because the gases persist long enough to diffuse across the planet.': 0.8623188405797102,
#  'Since the pre-industrial period, the average surface temperature over land regions has increased almost twice as fast as the global-average surface temperature.': 1.3115942028985508,
#  'This is because of the larger heat capacity of oceans, and because oceans lose more heat by evaporation.': 0.717391304347826,
#  'The rest has heated the atmosphere, melted ice, and warmed the continents.': 0.43478260869565216,
#  'The Northern Hemisphere and the North Pole have warmed much faster than the South Pole and Southern Hemisphere.': 0.2391304347826087,
#  'The Northern Hemisphere not only has much more land, but also more seasonal snow cover and sea ice.': 0.8985507246376812,
#  'As these surfaces flip from reflecting a lot of light to being dark after the ice has melted, they start absorbing more heat.': 0.5289855072463768,
#  'Local black carbon deposits on snow and ice also contribute to Arctic warming.': 1.4782608695652173,
#  'Arctic temperatures are increasing at over twice the rate of the rest of the world.': 0.427536231884058,
#  'Melting of glaciers and ice sheets in the Arctic disrupts ocean circulation, including a weakened Gulf Stream, further changing the climate.': 1.6231884057971016,
#  'The climate system experiences various cycles on its own which can last for years (such as the El Niño–Southern Oscillation), decades or even centuries.': 1.3623188405797102,
#  'Other changes are caused by an imbalance of energy that is "external" to the climate system, but not always external to the Earth.': 1.8550724637681162,
#  'To determine the human contribution to climate change, known internal climate variability and natural external forcings need to be ruled out.': 3.007246376811595,
#  'A key approach is to determine unique "fingerprints" for all potential causes, then compare these fingerprints with observed patterns of climate change.': 1.8405797101449275,
#  'For example, solar forcing can be ruled out as a major cause.': 0.31884057971014496,
#  'Its fingerprint would be warming in the entire atmosphere.': 0.9057971014492754,
#  'Yet, only the lower atmosphere has warmed, consistent with greenhouse gas forcing.': 0.7608695652173914,
#  'Attribution of recent climate change shows that the main driver is elevated greenhouse gases, with aerosols having a dampening effect.': 2.3550724637681157,
#  'The Earth absorbs sunlight, then radiates it as heat.': 0.5434782608695652,
#  'In 2019, the concentrations of CO2 and methane had increased by about 48% and 160%, respectively, since 1750.': 0.4347826086956522,
#  'These CO2 levels are higher than they have been at any time during the last 2 million years.': 0.4347826086956522,
#  'Concentrations of methane are far higher than they were over the last 800,000 years.': 0.39855072463768115,
#  'Global anthropogenic greenhouse gas emissions in 2018, excluding those from land use change, were equivalent to 52 billion tonnes of CO2.': 2.3115942028985508,
#  'Of these emissions, 72% was CO2, 19% was methane, 6% was nitrous oxide, and 3% was fluorinated gases.': 0.7753623188405797,
#  'CO2 emissions primarily come from burning fossil fuels to provide energy for transport, manufacturing, heating, and electricity.': 1.1956521739130437,
#  'Methane emissions come from livestock, manure, rice cultivation, landfills, wastewater, and coal mining, as well as oil and gas extraction.': 0.8913043478260871,
#  'Nitrous oxide emissions largely come from the microbial decomposition of fertiliser.': 0.572463768115942,
#  "Despite the contribution of deforestation to greenhouse gas emissions, the Earth's land surface, particularly its forests, remain a significant carbon sink for CO2.": 1.9710144927536228,
#  'Natural processes, such as carbon fixation in the soil and photosynthesis, more than offset the greenhouse gas contributions from deforestation.': 1.0144927536231885,
#  'The land-surface sink is estimated to remove about 29% of annual global CO2 emissions.': 0.963768115942029,
#  'The ocean also serves as a significant carbon sink via a two-step process.': 0.8043478260869564,
#  'First, CO2 dissolves in the surface water.': 0.2898550724637681,
#  "Afterwards, the ocean's overturning circulation distributes it deep into the ocean's interior, where it accumulates over time as part of the carbon cycle.": 0.7971014492753623,
#  "Over the last two decades, the world's oceans have absorbed 20 to 30% of emitted CO2.": 0.31884057971014496,
#  'Globally, aerosols have been declining since 1990, meaning that they no longer mask greenhouse gas warming as much.': 1.2391304347826086,
#  'Aerosols scatter and absorb solar radiation.': 0.2753623188405797,
#  "They also have indirect effects on the Earth's radiation budget.": 0.5579710144927535,
#  'Sulfate aerosols act as cloud condensation nuclei and lead to clouds that have more and smaller cloud droplets.': 0.2608695652173913,
#  'These clouds reflect solar radiation more efficiently than clouds with fewer and larger droplets.': 0.3550724637681159,
#  'They also reduce the growth of raindrops, which makes clouds more reflective to incoming sunlight.': 0.6304347826086956,
#  'Indirect effects of aerosols are the largest uncertainty in radiative forcing.': 0.3115942028985507,
#  'While aerosols typically limit global warming by reflecting sunlight, black carbon in soot that falls on snow or ice can contribute to global warming.': 2.77536231884058,
#  'Not only does this increase the absorption of sunlight, it also increases melting and sea-level rise.': 0.7028985507246377,
#  'Limiting new black carbon deposits in the Arctic could reduce global warming by 0.2 °C by 2050.': 1.6884057971014492,
#  "Humans change the Earth's surface mainly to create more agricultural land.": 1.2318840579710144,
#  "Today, agriculture takes up 34% of Earth's land area, while 26% is forests, and 30% is uninhabitable (glaciers, deserts, etc.).": 0.5507246376811593,
#  'The amount of forested land continues to decrease, largely due to conversion to cropland in the tropics.': 0.40579710144927533,
#  'This deforestation is the most significant aspect of land surface change affecting global warming.': 2.0434782608695654,
#  'Land use changes not only affect greenhouse gas emissions.': 1.4202898550724639,
#  'The type of vegetation in a region affects the local temperature.': 0.2028985507246377,
#  'It impacts how much of the sunlight gets reflected back into space (albedo), and how much heat is lost by evaporation.': 0.717391304347826,
#  'For instance, the change from a dark forest to grassland makes the surface lighter, causing it to reflect more sunlight.': 1.1159420289855073,
#  'Deforestation can also affect temperatures by modifying the release of chemical compounds that influence clouds, and by changing wind patterns.': 0.6376811594202898,
#  'Globally, these effects are estimated to have led to a slight cooling, dominated by an increase in surface albedo.': 0.572463768115942,
#  "As the Sun is the Earth's primary energy source, changes in incoming sunlight directly affect the climate system.": 1.9492753623188406,
#  'Solar irradiance has been measured directly by satellites, and indirect measurements are available from the early 1600s onwards.': 0.2608695652173913,
#  "There has been no upward trend in the amount of the Sun's energy reaching the Earth.": 0.6376811594202898,
#  'If solar variations were responsible for the observed warming, the troposphere and stratosphere would both warm.': 0.9999999999999999,
#  'Explosive volcanic eruptions represent the largest natural forcing over the industrial era.': 0.3695652173913043,
#  'When the eruption is sufficiently strong (with sulfur dioxide reaching the stratosphere), sunlight can be partially blocked for a couple of years.': 0.37681159420289845,
#  'The temperature signal lasts about twice as long.': 0.2318840579710145,
#  'In the industrial era, volcanic activity has had negligible impacts on global temperature trends.': 0.8695652173913043,
#  'Present-day volcanic CO2 emissions are equivalent to less than 1% of current anthropogenic CO2 emissions.': 1.1739130434782608,
#  'The response of the climate system to an initial forcing is modified by feedbacks: increased by self-reinforcing feedbacks and reduced by balancing feedbacks.': 1.6376811594202905,
#  'The main reinforcing feedbacks are the water-vapour feedback, the ice–albedo feedback, and the net effect of clouds.': 0.4202898550724638,
#  "The primary balancing mechanism is radiative cooling, as Earth's surface gives off more heat to space in response to rising temperature.": 0.9637681159420289,
#  'In addition to temperature feedbacks, there are feedbacks in the carbon cycle, such as the fertilizing effect of CO2 on plant growth.': 0.8550724637681159,
#  'Uncertainty over feedbacks is the major reason why different climate models project different magnitudes of warming for a given amount of emissions.': 2.4855072463768115,
#  'As the air is warmed by greenhouse gases, it can hold more moisture.': 0.6521739130434783,
#  'Water vapour is a potent greenhouse gas, so this further heats the atmosphere.': 0.7826086956521738,
#  'If cloud cover increases, more sunlight will be reflected back into space, cooling the planet.': 0.39855072463768115,
#  'If clouds become higher and thinner, they act as an insulator, reflecting heat from below back downwards and warming the planet.': 1.115942028985507,
#  'The effect of clouds is the largest source of feedback uncertainty.': 0.2898550724637681,
#  "Another major feedback is the reduction of snow cover and sea ice in the Arctic, which reduces the reflectivity of the Earth's surface.": 1.0362318840579712,
#  "More of the Sun's energy is now absorbed in these regions, contributing to amplification of Arctic temperature changes.": 0.9130434782608695,
#  'Arctic amplification is also melting permafrost, which releases methane and CO2 into the atmosphere.': 0.644927536231884,
#  'Climate change can also cause methane releases from wetlands, marine systems, and freshwater systems.': 2.079710144927537,
#  'Overall, climate feedbacks are expected to become increasingly positive.': 1.2246376811594206,
#  'Around half of human-caused CO2 emissions have been absorbed by land plants and by the oceans.': 0.8405797101449275,
#  'On land, elevated CO2 and an extended growing season have stimulated plant growth.': 0.34782608695652173,
#  'Soils contain large quantities of carbon and may release some when they heat up.': 0.8260869565217391,
#  'Overall, at higher CO2 concentrations the Earth will absorb a reduced fraction of our emissions.': 0.9420289855072463,
#  'A climate model is a representation of the physical, chemical, and biological processes that affect the climate system.': 2.2681159420289854,
#  'Models are used to calculate the degree of warming future emissions will cause when accounting for the strength of climate feedbacks.': 2.4202898550724634,
#  "Models also include natural processes like changes in the Earth's orbit, historical changes in the Sun's activity, and volcanic forcing.": 1.3405797101449273,
#  'The physical realism of models is tested by examining their ability to simulate contemporary or past climates.': 0.2608695652173913,
#  'Past models have underestimated the rate of Arctic shrinkage and underestimated the rate of precipitation increase.': 0.5579710144927537,
#  'Sea level rise since 1990 was underestimated in older models, but more recent models agree well with observations.': 0.8695652173913043,
#  'The 2017 United States-published National Climate Assessment notes that "climate models may still be underestimating or missing relevant feedback processes".': 2.492753623188407,
#  'A subset of climate models add societal factors to a simple physical climate model.': 2.2463768115942035,
#  'These models simulate how population, economic growth, and energy use affect – and interact with – the physical climate.': 1.7536231884057971,
#  'With this information, these models can produce scenarios of future greenhouse gas emissions.': 1.2028985507246377,
#  'This is then used as input for physical climate models to generate climate change projections.': 2.876811594202899,
#  'In some scenarios emissions continue to rise over the century, while others have reduced emissions.': 1.3115942028985508,
#  'Emissions scenarios can be combined with modelling of the carbon cycle to predict how atmospheric concentrations of greenhouse gases might change in the future.': 2.2173913043478257,
#  'These projections are based on climate models in combination with observations.': 1.2246376811594204,
#  'The remaining carbon budget is determined by modelling the carbon cycle and the climate sensitivity to greenhouse gases.': 2.239130434782609,
#  '[a] This corresponds to 10 to 13 years of current emissions.': 0.6304347826086956,
#  'There are high uncertainties about the budget.': 0.10869565217391304,
#  'For instance, it may be 100 gigatonnes of CO2 smaller due to methane release from permafrost and wetlands.': 0.4710144927536232,
#  'The environmental effects of climate change are broad and far-reaching, affecting oceans, ice, and weather.': 2.0942028985507246,
#  'Changes may occur gradually or rapidly.': 0.3550724637681159,
#  'Evidence for these effects comes from studying climate change in the past, from modelling, and from modern observations.': 1.8478260869565217,
#  'Since the 1950s, droughts and heat waves have appeared simultaneously with increasing frequency.': 0.5072463768115942,
#  'Extremely wet or dry events within the monsoon period have increased in India and East Asia.': 0.39855072463768115,
#  'The rainfall rate and intensity of hurricanes and typhoons is likely increasing.': 0.21739130434782608,
#  'Frequency of tropical cyclones has not increased as a result of climate change.': 1.8768115942028987,
#  'Global sea level is rising as a consequence of glacial melt, melt of the ice sheets in Greenland and Antarctica, and thermal expansion.': 1.1304347826086956,
#  'Between 1993 and 2020, the rise increased over time, averaging 3.3 ± 0.3 mm per year.': 0.5072463768115941,
#  'Over the 21st century, the IPCC projects that in a very high emissions scenario the sea level could rise by 61–110 cm.': 1.2463768115942029,
#  'Climate change has led to decades of shrinking and thinning of the Arctic sea ice.': 2.0942028985507246,
#  'Higher atmospheric CO2 concentrations have led to changes in ocean chemistry.': 0.5579710144927537,
#  'An increase in dissolved CO2 is causing oceans to acidify.': 0.2681159420289855,
#  'In addition, oxygen levels are decreasing as oxygen is less soluble in warmer water.': 0.4420289855072464,
#  'Dead zones in the ocean, regions with very little oxygen, are expanding too.': 0.3405797101449275,
#  'Some large-scale changes could occur over a short time period, such as a collapse of certain ocean currents.': 0.5942028985507246,
#  'The long-term effects of climate change include further ice melt, ocean warming, sea level rise, and ocean acidification.': 3.2246376811594204,
#  'On the timescale of centuries to millennia, the magnitude of climate change will be determined primarily by anthropogenic CO2 emissions.': 2.181159420289855,
#  "This is due to CO2's long atmospheric lifetime.": 0.2101449275362319,
#  'Oceanic CO2 uptake is slow enough that ocean acidification will continue for hundreds to thousands of years.': 0.35507246376811585,
#  'These emissions are estimated to have prolonged the current interglacial period by at least 100,000 years.': 0.7391304347826088,
#  'Sea level rise will continue over many centuries, with an estimated rise of 2.3 metres per degree Celsius (4.2 ft/°F) after 2000 years.': 0.9420289855072465,
#  'Recent warming has driven many terrestrial and freshwater species poleward and towards higher altitudes.': 0.8840579710144928,
#  'Higher atmospheric CO2 levels and an extended growing season have resulted in global greening.': 0.7246376811594204,
#  'However, heatwaves and drought have reduced ecosystem productivity in some regions.': 0.3043478260869565,
#  'The future balance of these opposing effects is unclear.': 0.1811594202898551,
#  'Climate change has contributed to the expansion of drier climate zones, such as the expansion of deserts in the subtropics.': 2.7391304347826093,
#  'The size and speed of global warming is making abrupt changes in ecosystems more likely.': 1.2898550724637683,
#  'Overall, it is expected that climate change will result in the extinction of many species.': 1.86231884057971,
#  'Ocean acidification makes it harder for organisms such as mussels, barnacles and corals to produce shells and skeletons; and heatwaves have bleached coral reefs.': 0.3768115942028985,
#  'Harmful algal blooms enhanced by climate change and eutrophication lower oxygen levels, disrupt food webs and cause great loss of marine life.': 2.079710144927536,
#  'Coastal ecosystems are under particular stress.': 0.15217391304347827,
#  'Almost half of global wetlands have disappeared due to climate change and other human impacts.': 2.427536231884058,
#  'Ecological collapse.': 0.028985507246376812,
#  'Bleaching has damaged the Great Barrier Reef and threatens reefs worldwide.': 0.10144927536231883,
#  'Extreme weather.': 0.09420289855072464,
#  'Drought and high temperatures worsened the 2020 bushfires in Australia.': 0.2101449275362319,
#  'Arctic warming.': 0.644927536231884,
#  'Permafrost thaws undermine infrastructure and release methane, a greenhouse gas.': 0.6086956521739131,
#  'Habitat destruction.': 0.014492753623188406,
#  'Many arctic animals rely on sea ice, which has been disappearing in a warming Arctic.': 1.181159420289855,
#  'Pest propagation.': 0.014492753623188406,
#  'Mild winters allow more pine beetles to survive to kill large swaths of forest.': 0.19565217391304346,
#  'The effects of climate change on humans have been detected worldwide.': 1.7608695652173914,
#  'They are mostly due to warming and shifts in precipitation.': 0.6884057971014492,
#  'Impacts can now be observed on all continents and ocean regions, with low-latitude, less developed areas facing the greatest risk.': 0.7463768115942029,
#  'Continued warming has potentially “severe, pervasive and irreversible impacts” for people and ecosystems.': 0.9999999999999999,
#  'The risks are unevenly distributed, but are generally greater for disadvantaged people in developing and developed countries.': 0.5942028985507246,
#  'The WHO has classified climate change as the greatest threat to global health in the 21st century.': 2.210144927536232,
#  'Extreme weather leads to injury and loss of life, and crop failures to undernutrition.': 0.22463768115942032,
#  'Various infectious diseases are more easily transmitted in a warmer climate, such as dengue fever and malaria.': 1.1159420289855073,
#  'Young children are the most vulnerable to food shortages.': 0.15217391304347827,
#  'Both children and older people are vulnerable to extreme heat.': 0.463768115942029,
#  'The World Health Organization (WHO) has estimated that between 2030 and 2050, climate change would cause around 250,000 additional deaths per year.': 2.27536231884058,
#  'They assessed deaths from heat exposure in elderly people, increases in diarrhea, malaria, dengue, coastal flooding, and childhood undernutrition.': 0.6449275362318839,
#  'Over 500,000 more adult deaths are projected yearly by 2050 due to reductions in food availability and quality.': 0.3043478260869565,
#  'Climate change is affecting food security.': 1.7463768115942029,
#  'It has caused reduction in global yields of maize, wheat, and soybeans between 1981 and 2010.': 0.5434782608695653,
#  'Future warming could further reduce global yields of major crops.': 1.2971014492753625,
#  'Crop production will probably be negatively affected in low-latitude countries, while effects at northern latitudes may be positive or negative.': 0.6666666666666666,
#  'Up to an additional 183 million people worldwide, particularly those with lower incomes, are at risk of hunger as a consequence of these impacts.': 0.5652173913043478,
#  'Climate change also impacts fish populations.': 2.0,
#  'Globally, less will be available to be fished.': 0.14492753623188406,
#  'Regions dependent on glacier water, regions that are already dry, and small islands have a higher risk of water stress due to climate change.': 2.4492753623188404,
#  'Economic damages due to climate change may be severe and there is a chance of disastrous tail-risk events.': 2.0144927536231885,
#  'Climate change has likely already increased global economic inequality, and this trend is projected to continue.': 2.420289855072464,
#  'Most of the severe impacts are expected in sub-Saharan Africa and South-East Asia.': 0.2826086956521739,
#  'The World Bank estimates that climate change could drive over 120 million people into poverty by 2030.': 2.0,
#  'Current inequalities between men and women, between rich and poor, and between different ethnicities have worsened due to climate variability and climate change.': 2.9347826086956523,
#  'Low-lying islands and coastal communities are threatened by sea level rise, which makes flooding more common.': 0.6231884057971014,
#  'Sometimes, land is permanently lost to the sea.': 0.35507246376811596,
#  'This could lead to statelessness for people in island nations, such as the Maldives and Tuvalu.': 0.32608695652173914,
#  'In some regions, the rise in temperature and humidity may be too severe for humans to adapt to.': 0.6956521739130435,
#  'These factors can drive environmental migration, both within and between countries.': 0.41304347826086957,
#  'More people are expected to be displaced because of sea level rise, extreme weather and conflict from increased competition over natural resources.': 1.0362318840579712,
#  'Climate change may also increase vulnerability, leading to "trapped populations" who are not able to move due to a lack of resources.': 2.3260869565217397,
#  'Environmental migration.': 0.10144927536231885,
#  'Sparser rainfall leads to desertification that harms agriculture and can displace populations.': 0.15942028985507245,
#  'Shown: Telly, Mali (2008).': 0.036231884057971016,
#  'Agricultural changes.': 0.21014492753623187,
#  'Droughts, rising temperatures, and extreme weather negatively impact agriculture.': 0.34782608695652173,
#  'Shown: Texas, US (2013).': 0.036231884057971016,
#  'Tidal flooding.': 0.057971014492753624,
#  'Sea-level rise increases flooding in low-lying coastal regions.': 0.391304347826087,
#  'Shown: Venice, Italy (2004).': 0.036231884057971016,
#  'Storm intensification.': 0.021739130434782608,
#  'Bangladesh after Cyclone Sidr (2007) is an example of catastrophic flooding from increased rainfall.': 0.3188405797101449,
#  'Heat wave intensification.': 0.2753623188405797,
#  'Events like the June 2019 European heat wave are becoming more common.': 0.4565217391304348,
#  'Climate change can be mitigated by reducing greenhouse gas emissions and by enhancing sinks that absorb greenhouse gases from the atmosphere.': 3.3115942028985508,
#  'This requires far-reaching, systemic changes on an unprecedented scale in energy, land, cities, transport, buildings, and industry.': 0.8623188405797101,
#  'An even greater level of reduction is required to meet the 1.5 °C goal.': 0.35507246376811596,
#  'Other approaches to mitigating climate change have a higher level of risk.': 1.9492753623188406,
#  'Scenarios that limit global warming to 1.5 °C typically project the large-scale use of carbon dioxide removal methods over the 21st century.': 1.7463768115942029,
#  'There are concerns, though, about over-reliance on these technologies, and environmental impacts.': 0.2753623188405797,
#  'Solar radiation management (SRM) is also a possible supplement to deep reductions in emissions.': 0.9130434782608694,
#  'However, SRM would raise significant ethical and legal issues, and the risks are poorly understood.': 0.42753623188405787,
#  'Renewable energy is key to limiting climate change.': 2.028985507246377,
#  "Fossil fuels accounted for 80% of the world's energy in 2018.": 0.5507246376811594,
#  'The remaining share was split between nuclear power and renewables (including solar and wind power, bioenergy, geothermal energy, and hydropower).': 0.7971014492753622,
#  'That mix is projected to change significantly over the next 30 years.': 0.7608695652173912,
#  'Solar and wind have seen substantial growth and progress over the last few years.': 0.4057971014492754,
#  'Solar panels and onshore wind are the cheapest forms of adding new power generation capacity in most countries.': 0.6304347826086957,
#  'Renewables represented 75% of all new electricity generation installed in 2019, nearly all solar and wind.': 0.37681159420289856,
#  'Meanwhile, nuclear power share remains the same but costs are increasing.': 0.2536231884057971,
#  'Nuclear power generation is now several times more expensive per megawatt-hour than wind and solar.': 0.4202898550724638,
#  'The use of electricity for heating and transport, would rise to the point where electricity becomes the largest form of energy.': 1.0579710144927537,
#  'Investment in coal would be eliminated and coal use nearly phased out by 2050.': 0.4710144927536231,
#  'In transport, emissions can be reduced fast by a switch to electric vehicles.': 0.6739130434782609,
#  'Public transport and active transport (cycling and walking) also produce less CO2.': 0.572463768115942,
#  'For shipping and flying, low-carbon fuels can be used to reduce emissions.': 0.7101449275362319,
#  'Heating would be increasingly decarbonised with technologies like heat pumps.': 0.6159420289855072,
#  'There are obstacles to the continued rapid growth of renewables.': 0.16666666666666666,
#  'For solar and wind power, a key challenge is their intermittency and seasonal variability.': 0.355072463768116,
#  'Traditionally, hydro dams with reservoirs and conventional power plants have been used when variable energy production is low.': 0.6811594202898551,
#  'Intermittency is further countered by expanding battery storage and matching energy demand and supply.': 0.44202898550724634,
#  'Long-distance transmission can smooth variability of renewable output across wider geographic areas.': 0.2028985507246377,
#  'Hydropower growth has been slowing and is set to decline further due to concerns about social and environmental impacts.': 0.5289855072463768,
#  'Low-carbon energy improves human health by minimising climate change.': 2.0652173913043477,
#  'It also has the near-term benefit of reducing air pollution deaths, which were estimated at 7 million annually in 2016.': 0.572463768115942,
#  'Reducing energy demand is another major aspect of reducing emissions.': 1.0579710144927534,
#  'If less energy is needed, there is more flexibility for clean energy development.': 0.7898550724637682,
#  'It also makes it easier to manage the electricity grid, and minimises carbon-intensive infrastructure development.': 0.44202898550724623,
#  'Major increases in energy efficiency investment will be required to achieve climate goals, comparable to the level of investment in renewable energy.': 2.094202898550725,
#  'Several COVID-19 related changes in energy use patterns, energy efficiency investments, and funding have made forecasts for this decade more difficult and uncertain.': 1.1449275362318838,
#  'Strategies to reduce energy demand vary by sector.': 0.5289855072463768,
#  'In transport, passengers and freight can switch to more efficient travel modes, such as buses and trains, or use electric vehicles.': 0.3115942028985508,
#  'Industrial strategies to reduce energy demand include improving heating systems and motors, designing less energy-intensive products, and increasing product lifetimes.': 0.956521739130435,
#  'In the building sector the focus is on better design of new buildings, and higher levels of energy efficiency in retrofitting.': 0.673913043478261,
#  'The use of technologies like heat pumps can also increase building energy efficiency.': 1.1884057971014492,
#  'A set of actions could reduce agriculture and forestry-based emissions by two thirds from 2010 levels.': 0.9637681159420289,
#  'Steel and cement production, responsible for about 13% of industrial CO2 emissions, present particular challenges.': 0.7101449275362319,
#  'Natural carbon sinks can be enhanced to sequester significantly larger amounts of CO2 beyond naturally occurring levels.': 0.6739130434782608,
#  'Reforestation and tree planting on non-forest lands are among the most mature sequestration techniques, although the latter raises food security concerns.': 0.30434782608695654,
#  'Soil carbon sequestration and coastal carbon sequestration are less understood options.': 0.8695652173913042,
#  'The feasibility of land-based negative emissions methods for mitigation are uncertain; the IPCC has described mitigation strategies based on them as risky.': 0.8333333333333335,
#  'This technique, in combination with bio-energy (BECCS) can result in net negative emissions: CO2 is drawn from the atmosphere.': 0.7898550724637681,
#  'Policy decisions that rely on carbon dioxide removal increase the risk of global warming rising beyond international goals.': 1.789855072463768,
#  'Adaptation is "the process of adjustment to current or expected changes in climate and its effects".': 1.4927536231884058,
#  'Without additional mitigation, adaptation cannot avert the risk of "severe, widespread and irreversible" impacts.': 0.5507246376811594,
#  'More severe climate change requires more transformative adaptation, which can be prohibitively expensive.': 1.8115942028985508,
#  'The capacity and potential for humans to adapt is unevenly distributed across different regions and populations, and developing countries generally have less.': 0.8043478260869565,
#  'Many countries have implemented adaptation policies.': 0.44202898550724634,
#  'However, there is a considerable gap between necessary and available finance.': 0.12318840579710146,
#  'Adaptation to sea level rise consists of avoiding at-risk areas, learning to live with increased flooding and protection.': 0.8478260869565216,
#  'If that fails, managed retreat may be needed.': 0.18840579710144928,
#  'There are economic barriers for tackling dangerous heat impact.': 0.34782608695652173,
#  'Avoiding strenuous work or having air conditioning is not possible for everybody.': 0.1739130434782609,
#  'In agriculture, adaptation options include a switch to more sustainable diets, diversification, erosion control and genetic improvements for increased tolerance to a changing climate.': 1.5507246376811592,
#  'Insurance allows for risk-sharing, but is often difficult to get for people on lower incomes.': 0.2826086956521739,
#  'Education, migration and early warning systems can reduce climate vulnerability.': 1.2173913043478262,
#  'Ecosystems adapt to climate change, a process that can be supported by human intervention.': 1.884057971014493,
#  'By increasing connectivity between ecosystems, species can migrate to more favourable climate conditions.': 1.2246376811594204,
#  'Species can also be introduced to areas acquiring a favorable climate.': 1.318840579710145,
#  'Protection and restoration of natural and semi-natural areas helps build resilience, making it easier for ecosystems to adapt.': 0.40579710144927533,
#  'Many of the actions that promote adaptation in ecosystems, also help humans adapt via ecosystem-based adaptation.': 0.7028985507246377,
#  'For instance, restoration of natural fire regimes makes catastrophic fires less likely, and reduces human exposure.': 0.5434782608695651,
#  'Giving rivers more space allows for more water storage in the natural system, reducing flood risk.': 0.5507246376811594,
#  'Restored forest acts as a carbon sink, but planting trees in unsuitable regions can exacerbate climate impacts.': 1.7318840579710144,
#  'There are synergies and trade-offs between adaptation and mitigation.': 0.17391304347826086,
#  'Adaptation often offer short-term benefits, whereas mitigation has longer-term benefits.': 0.2971014492753623,
#  'Increased use of air conditioning allows people to better cope with heat, but increases energy demand.': 1.2681159420289856,
#  'Compact urban development may lead to reduced emissions from transport and construction.': 0.8333333333333333,
#  'At the same time, it may increase the urban heat island effect, leading to higher temperatures and increased exposure.': 1.1231884057971016,
#  'Increased food productivity has large benefits for both adaptation and mitigation.': 0.5579710144927537,
#  'Countries that are most vulnerable to climate change have typically been responsible for a small share of global emissions.': 2.8405797101449273,
#  'This raises questions about justice and fairness.': 0.043478260869565216,
#  'Climate change is strongly linked to sustainable development.': 1.7173913043478262,
#  'Limiting global warming makes it easier to achieve sustainable development goals, such as eradicating poverty and reducing inequalities.': 1.376811594202899,
#  'The connection is recognised in Sustainable Development Goal 13 which is to "[t]ake urgent action to combat climate change and its impacts".': 1.9710144927536233,
#  'The goals on food, clean water and ecosystem protection have synergies with climate mitigation.': 1.4202898550724639,
#  'The geopolitics of climate change is complex.': 1.6231884057971016,
#  'This framing has been challenged.': 0.014492753623188406,
#  'For instance, the benefits of a coal phase-out to public health and local environments exceed the costs in almost all regions.': 0.45652173913043476,
#  'A wide range of policies, regulations, and laws are being used to reduce emissions.': 0.7391304347826086,
#  'As of 2019, carbon pricing covers about 20% of global greenhouse gas emissions.': 1.6376811594202898,
#  'Carbon can be priced with carbon taxes and emissions trading systems.': 1.1594202898550725,
#  'Direct global fossil fuel subsidies reached $319 billion in 2017, and $5.2 trillion when indirect costs such as air pollution are priced in.': 0.855072463768116,
#  'Ending these can cause a 28% reduction in global carbon emissions and a 46% reduction in air pollution deaths.': 1.5144927536231882,
#  'Subsidies could be used to support the transition to clean energy instead.': 0.5652173913043479,
#  'More direct methods to reduce greenhouse gases include vehicle efficiency standards, renewable fuel standards, and air pollution regulations on heavy industry.': 1.1014492753623188,
#  'Several countries require utilities to increase the share of renewables in power production.': 0.6521739130434782,
#  'Policy designed through the lens of climate justice tries to address human rights issues and social inequality.': 1.2536231884057976,
#  'For instance, wealthy nations responsible for the largest share of emissions would have to pay poorer countries to adapt.': 1.1666666666666667,
#  'As the use of fossil fuels is reduced, jobs in the sector are being lost.': 0.4130434782608695,
#  'To achieve a just transition, these people would need to be retrained for other jobs.': 0.41304347826086957,
#  'Communities with many fossil fuel workers would need additional investments.': 0.572463768115942,
#  'Nearly all countries in the world are parties to the 1994 United Nations Framework Convention on Climate Change (UNFCCC).': 2.1159420289855073,
#  'The goal of the UNFCCC is to prevent dangerous human interference with the climate system.': 1.2898550724637683,
#  'The UNFCCC does not itself restrict emissions but rather provides a framework for protocols that do.': 0.5362318840579711,
#  'Global emissions have risen since the UNFCCC was signed.': 1.0144927536231885,
#  'Its yearly conferences are the stage of global negotiations.': 0.4420289855072464,
#  'The 1997 Kyoto Protocol extended the UNFCCC and included legally binding commitments for most developed countries to limit their emissions.': 1.0072463768115942,
#  'Per-capita emissions were also still relatively low in developing countries and developing countries would need to emit more to meet their development needs.': 1.710144927536232,
#  'The 2009 Copenhagen Accord has been widely portrayed as disappointing because of its low goals, and was rejected by poorer nations including the G77.': 0.3115942028985508,
#  'Associated parties aimed to limit the global temperature rise to below 2 °C.': 0.7971014492753623,
#  'As of 2020[update], the fund has failed to reach its expected target, and risks a shrinkage in its funding.': 0.20289855072463767,
#  'The agreement replaced the Kyoto Protocol.': 0.18840579710144928,
#  'Unlike Kyoto, no binding emission targets were set in the Paris Agreement.': 0.30434782608695654,
#  'Instead, a set of procedures was made binding.': 0.17391304347826086,
#  'Countries have to regularly set ever more ambitious goals and reevaluate these goals every five years.': 0.5942028985507246,
#  'The Paris Agreement restated that developing countries must be financially supported.': 0.4855072463768116,
#  'This made the Montreal Protocol a stronger agreement against climate change.': 1.8333333333333335,
#  'In 2019, the United Kingdom parliament became the first national government to declare a climate emergency.': 1.1884057971014492,
#  'Other countries and jurisdictions followed suit.': 0.2608695652173913,
#  'That same year, the European Parliament declared a "climate and environmental emergency".': 1.2246376811594204,
#  'The European Commission presented its European Green Deal with the goal of making the EU carbon-neutral by 2050.': 0.2391304347826087,
#  'Major countries in Asia have made similar pledges: South Korea and Japan have committed to become carbon-neutral by 2050, and China by 2060.': 0.4999999999999999,
#  'While India has strong incentives for renewables, it also plans a significant expansion of coal in the country.': 0.4492753623188406,
#  'There is a near-complete scientific consensus that the climate is warming and that this is caused by human activities.': 1.7898550724637683,
#  'Agreement in recent literature reached over 99%.': 0.16666666666666669,
#  'No scientific body of national or international standing disagrees with this view.': 0.15217391304347827,
#  'Consensus has further developed that some form of action should be taken to protect people against the impacts of climate change.': 2.050724637681159,
#  'National science academies have called on world leaders to cut global emissions.': 1.0217391304347825,
#  'Scientific discussion takes place in journal articles that are peer-reviewed.': 0.11594202898550725,
#  'Scientists assess these every few years in the Intergovernmental Panel on Climate Change reports.': 1.8333333333333335,
#  'The 2021 IPCC Assessment Report stated that it is "unequivocal" that climate change is caused by humans.': 1.8043478260869565,
#  'Like the tobacco industry, the main strategy of these groups has been to manufacture doubt about scientific data and results.': 0.2608695652173913,
#  'Strategies to promote these ideas include criticism of scientific institutions, and questioning the motives of individual scientists.': 0.30434782608695654,
#  'An echo chamber of climate-denying blogs and media has further fomented misunderstanding of climate change.': 1.6666666666666667,
#  'Climate change came to international public attention in the late 1980s.': 1.746376811594203,
#  'Due to media coverage in the early 1990s, people often confused climate change with other environmental issues like ozone depletion.': 2.1521739130434785,
#  'Significant regional, gender, age and political differences exist in both public concern for, and understanding of, climate change.': 1.855072463768116,
#  'More highly educated people, and in some countries, women and younger people, were more likely to see climate change as a serious threat.': 2.2246376811594204,
#  'Partisan gaps also exist in many countries, and countries with high CO2 emissions tend to be less concerned.': 1.4492753623188406,
#  'Views on causes of climate change vary widely between countries.': 1.9202898550724639,
#  'Higher levels of worry are associated with stronger public support for policies that address climate change.': 1.9782608695652175,
#  'Climate protests have risen in popularity in the 2010s.': 1.0507246376811596,
#  'These protests demand that political leaders take action to prevent climate change.': 1.8043478260869565,
#  'They can take the form of public demonstrations, fossil fuel divestment, lawsuits and other activities.': 0.3695652173913043,
#  'Prominent demonstrations include the School Strike for Climate.': 1.1231884057971016,
#  'In this initiative, young people across the globe have been protesting since 2018 by skipping school on Fridays, inspired by Swedish teenager Greta Thunberg.': 0.3478260869565216,
#  'Mass civil disobedience actions by groups like Extinction Rebellion have protested by disrupting roads and public transport.': 0.31884057971014496,
#  'Litigation is increasingly used as a tool to strengthen climate action from public institutions and companies.': 1.2681159420289858,
#  'Activists also initiate lawsuits which target governments and demand that they take ambitious action or enforce existing laws on climate change.': 2.0724637681159424,
#  'Lawsuits against fossil-fuel companies generally seek compensation for loss and damage.': 0.1449275362318841,
#  "In the 1820s, Joseph Fourier proposed the greenhouse effect to explain why Earth's temperature was higher than the sun's energy alone could explain.": 1.3115942028985508,
#  "Earth's atmosphere is transparent to sunlight, so sunlight reaches the surface where it is converted to heat.": 0.9782608695652175,
#  'However, the atmosphere is not transparent to heat radiating from the surface, and captures some of that heat which warms the planet.': 0.963768115942029,
#  'However, water vapour and some gases (in particular methane and carbon dioxide) absorb radiated heat and re-radiate that heat within the atmosphere.': 1.6376811594202898,
#  'Tyndall proposed that changes in the concentrations of these gases may have caused climatic changes in the past, including ice ages.': 1.0869565217391306,
#  'Svante Arrhenius noted that water vapour in air continuously varied, but the CO2 concentration in air was influenced by long-term geological processes.': 0.49275362318840565,
#  'Arrhenius calculated the temperature increase expected from doubling CO2 to be around 5–6 °C.': 0.42028985507246375,
#  'Other scientists were initially sceptical and believed the greenhouse effect to be saturated so that adding more CO2 would make no difference.': 0.6956521739130435,
#  'They thought climate would be self-regulating.': 1.1956521739130435,
#  'From 1938 onwards Guy Stewart Callendar published evidence that climate was warming and CO2 levels rising, but his calculations met the same objections.': 1.8260869565217392,
#  'In the 1950s, Gilbert Plass created a detailed computer model that included different atmospheric layers and the infrared spectrum.': 0.23913043478260873,
#  'This model predicted that increasing CO2 levels would cause warming.': 1.0072463768115942,
#  'The two scientists subsequently helped Charles Keeling to begin a record of continued increase, which has been termed the "Keeling Curve".': 0.36231884057971014,
#  "Scientists alerted the public, and the dangers were highlighted at James Hansen's 1988 Congressional testimony.": 0.21014492753623193,
#  "The Intergovernmental Panel on Climate Change, set up in 1988 to provide formal advice to the world's governments, spurred interdisciplinary research.": 1.8623188405797104}

# %% [markdown]
# # Getting Best lines

# %%
import heapq

# %%
# getting best lines
number_of_best_lines = 5
best_lines = heapq.nlargest(number_of_best_lines, sent_scores, key=sent_scores.get)

# %%
best_lines
# Out:
# ['Global warming usually refers to human-induced warming of the Earth system, whereas climate change can refer to natural or anthropogenic change.',
#  'Climate change can be mitigated by reducing greenhouse gas emissions and by enhancing sinks that absorb greenhouse gases from the atmosphere.',
#  'The long-term effects of climate change include further ice melt, ocean warming, sea level rise, and ocean acidification.',
#  'To determine the human contribution to climate change, known internal climate variability and natural external forcings need to be ruled out.',
#  " Contemporary climate change includes both global warming and its impacts on Earth's weather patterns."]

# %%
for sent in best_lines: print(sent)
# Out:
# Global warming usually refers to human-induced warming of the Earth system, whereas climate change can refer to natural or anthropogenic change.
# Climate change can be mitigated by reducing greenhouse gas emissions and by enhancing sinks that absorb greenhouse gases from the atmosphere.
# The long-term effects of climate change include further ice melt, ocean warming, sea level rise, and ocean acidification.
# To determine the human contribution to climate change, known internal climate variability and natural external forcings need to be ruled out.
#  Contemporary climate change includes both global warming and its impacts on Earth's weather patterns.
